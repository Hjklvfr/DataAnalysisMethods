# %% [markdown]
# # Lab 4

# %% [markdown]
# Web crawlers are called such because they crawl across the Web. At their core is an element of
# recursion. They must retrieve page contents for a URL, examine that page for another URL, and retrieve
# that page, ad infinitum.
# The recommended Python library for this assignment is Scrapy. Using other libraries like pandas and
# matplotlib is allowed.
# More about Scapy crawlers: https://doc.scrapy.org/en/latest/topics/spiders.html#crawlspider
# Working process:
# 1. Install Scrapy.
# 2. Extract data from Steam (https://store.steampowered.com/). Using CrawlSpider from Scrapy get the
# following info: Game title, release date, developer, publisher, popular user-defined tags for a product
# from first 1000 products of “Top Sellers”.
# <br>
# <br>
# **Advanced task:** to get all the whole tags list available by “+” button.
# Note: For extracting tags, you can use CSS and XPath selectors.
# 3. Group your games dataset by year. Name 3 the most popular game tags in each year. Name the least
# popular game tags in each year.
# 4. For these tags, print game names that have such tags (considering the proper year).
# Note: e.g., if tag “Open World” was popular in 2020, but was not in a top in 2019, only game titles with
# tag “Open World” from 2020 should be printed.

# %%
import os
from modules.vkapi import VkApi
import pandas as pd
import seaborn as sns
import pymongo

from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
client = pymongo.MongoClient(os.getenv("MONGO_URL"))
products = client['steam']['products']

df = pd.DataFrame(list(products.find({})))
df
# Out:
#           _id         developer                    publisher release_date  \
# 0         730             Valve                        Valve   2012-08-21
# 1      250900     Nicalis, Inc.                Nicalis, Inc.   2014-11-04
# 2      898890  Herobeat Studios                   HandyGames   2022-07-19
# 3     1426300     Nicalis, Inc.                Nicalis, Inc.   2021-03-31
# 4     1973530       ProjectMoon                  ProjectMoon   2023-02-26
# ...       ...               ...                          ...          ...
# 1445   979650       Konfa Games                  Konfa Games   2018-11-15
# 1446   584091   Tarsier Studios  BANDAI NAMCO Entertainement          NaN
# 1447  1199450  UNREAL DARK STUD   Moment Interactive Limited   2020-06-05
# 1448   401190       Racing Bros                      ANPA.US   2015-09-17
# 1449  1148100       Arkuda Inc.                  Arkuda Inc.   2022-02-21
#
#                                        title  \
# 0                           Counter-Strike 2
# 1              The Binding of Isaac: Rebirth
# 2            Endling - Extinction is Forever
# 3           The Binding of Isaac: Repentance
# 4                             Limbus Company
# ...                                      ...
# 1445               Despotism 3k - Soundtrack
# 1446  Little Nightmares - Upside-down Teapot
# 1447                             Dark Raider
# 1448                           Dinosaur Hunt
# 1449                        Life on the Hook
#
#                                                    tags
# 0     [FPS, Shooter, Multiplayer, Competitive, Actio...
# 1     [Action Roguelike, Roguelike, Indie, Replay Va...
# 2     [Emotional, Adventure, Atmospheric, Indie, Sur...
# 3     [Action, Adventure, RPG, Roguelike, Difficult,...
# 4     [Lore-Rich, Story Rich, Turn-Based Tactics, RP...
# ...                                                 ...
# 1445                                  [Indie, Strategy]
# 1446                                [Adventure, Horror]
# 1447  [Action, Adventure, Indie, Violent, Gore, Earl...
# 1448  [Dinosaurs, Action, Indie, Adventure, Multipla...
# 1449  [Atmospheric, Story Rich, Walking Simulator, E...
#
# [1450 rows x 6 columns]

# %%
df['release_date'] = pd.to_datetime(df['release_date'])
df
# Out:
#           _id         developer                    publisher release_date  \
# 0         730             Valve                        Valve   2012-08-21
# 1      250900     Nicalis, Inc.                Nicalis, Inc.   2014-11-04
# 2      898890  Herobeat Studios                   HandyGames   2022-07-19
# 3     1426300     Nicalis, Inc.                Nicalis, Inc.   2021-03-31
# 4     1973530       ProjectMoon                  ProjectMoon   2023-02-26
# ...       ...               ...                          ...          ...
# 1445   979650       Konfa Games                  Konfa Games   2018-11-15
# 1446   584091   Tarsier Studios  BANDAI NAMCO Entertainement          NaT
# 1447  1199450  UNREAL DARK STUD   Moment Interactive Limited   2020-06-05
# 1448   401190       Racing Bros                      ANPA.US   2015-09-17
# 1449  1148100       Arkuda Inc.                  Arkuda Inc.   2022-02-21
#
#                                        title  \
# 0                           Counter-Strike 2
# 1              The Binding of Isaac: Rebirth
# 2            Endling - Extinction is Forever
# 3           The Binding of Isaac: Repentance
# 4                             Limbus Company
# ...                                      ...
# 1445               Despotism 3k - Soundtrack
# 1446  Little Nightmares - Upside-down Teapot
# 1447                             Dark Raider
# 1448                           Dinosaur Hunt
# 1449                        Life on the Hook
#
#                                                    tags
# 0     [FPS, Shooter, Multiplayer, Competitive, Actio...
# 1     [Action Roguelike, Roguelike, Indie, Replay Va...
# 2     [Emotional, Adventure, Atmospheric, Indie, Sur...
# 3     [Action, Adventure, RPG, Roguelike, Difficult,...
# 4     [Lore-Rich, Story Rich, Turn-Based Tactics, RP...
# ...                                                 ...
# 1445                                  [Indie, Strategy]
# 1446                                [Adventure, Horror]
# 1447  [Action, Adventure, Indie, Violent, Gore, Earl...
# 1448  [Dinosaurs, Action, Indie, Adventure, Multipla...
# 1449  [Atmospheric, Story Rich, Walking Simulator, E...
#
# [1450 rows x 6 columns]

# %%
df['year'] = df['release_date'].dt.year
df
# Out:
#           _id         developer                    publisher release_date  \
# 0         730             Valve                        Valve   2012-08-21
# 1      250900     Nicalis, Inc.                Nicalis, Inc.   2014-11-04
# 2      898890  Herobeat Studios                   HandyGames   2022-07-19
# 3     1426300     Nicalis, Inc.                Nicalis, Inc.   2021-03-31
# 4     1973530       ProjectMoon                  ProjectMoon   2023-02-26
# ...       ...               ...                          ...          ...
# 1445   979650       Konfa Games                  Konfa Games   2018-11-15
# 1446   584091   Tarsier Studios  BANDAI NAMCO Entertainement          NaT
# 1447  1199450  UNREAL DARK STUD   Moment Interactive Limited   2020-06-05
# 1448   401190       Racing Bros                      ANPA.US   2015-09-17
# 1449  1148100       Arkuda Inc.                  Arkuda Inc.   2022-02-21
#
#                                        title  \
# 0                           Counter-Strike 2
# 1              The Binding of Isaac: Rebirth
# 2            Endling - Extinction is Forever
# 3           The Binding of Isaac: Repentance
# 4                             Limbus Company
# ...                                      ...
# 1445               Despotism 3k - Soundtrack
# 1446  Little Nightmares - Upside-down Teapot
# 1447                             Dark Raider
# 1448                           Dinosaur Hunt
# 1449                        Life on the Hook
#
#                                                    tags    year
# 0     [FPS, Shooter, Multiplayer, Competitive, Actio...  2012.0
# 1     [Action Roguelike, Roguelike, Indie, Replay Va...  2014.0
# 2     [Emotional, Adventure, Atmospheric, Indie, Sur...  2022.0
# 3     [Action, Adventure, RPG, Roguelike, Difficult,...  2021.0
# 4     [Lore-Rich, Story Rich, Turn-Based Tactics, RP...  2023.0
# ...                                                 ...     ...
# 1445                                  [Indie, Strategy]  2018.0
# 1446                                [Adventure, Horror]     NaN
# 1447  [Action, Adventure, Indie, Violent, Gore, Earl...  2020.0
# 1448  [Dinosaurs, Action, Indie, Adventure, Multipla...  2015.0
# 1449  [Atmospheric, Story Rich, Walking Simulator, E...  2022.0
#
# [1450 rows x 7 columns]

# %%
df['tags'] = df['tags'].astype('str')
# Out:
#           _id         developer                    publisher release_date  \
# 0         730             Valve                        Valve   2012-08-21
# 1      250900     Nicalis, Inc.                Nicalis, Inc.   2014-11-04
# 2      898890  Herobeat Studios                   HandyGames   2022-07-19
# 3     1426300     Nicalis, Inc.                Nicalis, Inc.   2021-03-31
# 4     1973530       ProjectMoon                  ProjectMoon   2023-02-26
# ...       ...               ...                          ...          ...
# 1445   979650       Konfa Games                  Konfa Games   2018-11-15
# 1446   584091   Tarsier Studios  BANDAI NAMCO Entertainement          NaT
# 1447  1199450  UNREAL DARK STUD   Moment Interactive Limited   2020-06-05
# 1448   401190       Racing Bros                      ANPA.US   2015-09-17
# 1449  1148100       Arkuda Inc.                  Arkuda Inc.   2022-02-21
#
#                                        title  \
# 0                           Counter-Strike 2
# 1              The Binding of Isaac: Rebirth
# 2            Endling - Extinction is Forever
# 3           The Binding of Isaac: Repentance
# 4                             Limbus Company
# ...                                      ...
# 1445               Despotism 3k - Soundtrack
# 1446  Little Nightmares - Upside-down Teapot
# 1447                             Dark Raider
# 1448                           Dinosaur Hunt
# 1449                        Life on the Hook
#
#                                                    tags    year  \
# 0     [FPS, Shooter, Multiplayer, Competitive, Actio...  2012.0
# 1     [Action Roguelike, Roguelike, Indie, Replay Va...  2014.0
# 2     [Emotional, Adventure, Atmospheric, Indie, Sur...  2022.0
# 3     [Action, Adventure, RPG, Roguelike, Difficult,...  2021.0
# 4     [Lore-Rich, Story Rich, Turn-Based Tactics, RP...  2023.0
# ...                                                 ...     ...
# 1445                                  [Indie, Strategy]  2018.0
# 1446                                [Adventure, Horror]     NaN
# 1447  [Action, Adventure, Indie, Violent, Gore, Earl...  2020.0
# 1448  [Dinosaurs, Action, Indie, Adventure, Multipla...  2015.0
# 1449  [Atmospheric, Story Rich, Walking Simulator, E...  2022.0
#
#                                                   tags1
# 0     ['FPS', 'Shooter', 'Multiplayer', 'Competitive...
# 1     ['Action Roguelike', 'Roguelike', 'Indie', 'Re...
# 2     ['Emotional', 'Adventure', 'Atmospheric', 'Ind...
# 3     ['Action', 'Adventure', 'RPG', 'Roguelike', 'D...
# 4     ['Lore-Rich', 'Story Rich', 'Turn-Based Tactic...
# ...                                                 ...
# 1445                              ['Indie', 'Strategy']
# 1446                            ['Adventure', 'Horror']
# 1447  ['Action', 'Adventure', 'Indie', 'Violent', 'G...
# 1448  ['Dinosaurs', 'Action', 'Indie', 'Adventure', ...
# 1449  ['Atmospheric', 'Story Rich', 'Walking Simulat...
#
# [1450 rows x 8 columns]

# %%
df['tags'].str.strip('[]').str.split(', ')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 df['tags'].str.strip('[]').str.split(', ')
#
# File ~\AppData\Local\pypoetry\Cache\virtualenvs\data-analysis-methods-99e_IxHd-py3.12\Lib\site-packages\pandas\core\generic.py:6299, in NDFrame.__getattr__(self, name)
#    6292 if (
#    6293     name not in self._internal_names_set
#    6294     and name not in self._metadata
#    6295     and name not in self._accessors
#    6296     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297 ):
#    6298     return self[name]
# -> 6299 return object.__getattribute__(self, name)
#
# File ~\AppData\Local\pypoetry\Cache\virtualenvs\data-analysis-methods-99e_IxHd-py3.12\Lib\site-packages\pandas\core\accessor.py:224, in CachedAccessor.__get__(self, obj, cls)
#     221 if obj is None:
#     222     # we're accessing the attribute of the class, i.e., Dataset.geo
#     223     return self._accessor
# --> 224 accessor_obj = self._accessor(obj)
#     225 # Replace the property with the accessor object. Inspired by:
#     226 # https://www.pydanny.com/cached-property.html
#     227 # We need to use object.__setattr__ because we overwrite __setattr__ on
#     228 # NDFrame
#     229 object.__setattr__(obj, self._name, accessor_obj)
#
# File ~\AppData\Local\pypoetry\Cache\virtualenvs\data-analysis-methods-99e_IxHd-py3.12\Lib\site-packages\pandas\core\strings\accessor.py:191, in StringMethods.__init__(self, data)
#     188 def __init__(self, data) -> None:
#     189     from pandas.core.arrays.string_ import StringDtype
# --> 191     self._inferred_dtype = self._validate(data)
#     192     self._is_categorical = isinstance(data.dtype, CategoricalDtype)
#     193     self._is_string = isinstance(data.dtype, StringDtype)
#
# File ~\AppData\Local\pypoetry\Cache\virtualenvs\data-analysis-methods-99e_IxHd-py3.12\Lib\site-packages\pandas\core\strings\accessor.py:245, in StringMethods._validate(data)
#     242 inferred_dtype = lib.infer_dtype(values, skipna=True)
#     244 if inferred_dtype not in allowed_types:
# --> 245     raise AttributeError("Can only use .str accessor with string values!")
#     246 return inferred_dtype
#
# AttributeError: Can only use .str accessor with string values!
